# %% [markdown]
# ## Evaluation of UTOPIA's performance in predicting MPs size dristributionsusing the monaco Monte Carlo framework
# #### (https://monaco.readthedocs.io/en/latest/)
#
# With this script we preform an evaluation of UTOPIA's size distribution predictive capacity by comparing predicted size distributions in targeted compartmanes aginst observed MPs size distributions reported in the compilation of published datasets by Kooi et al.

# %% [markdown]
# ### Import the necessary libraries

# %%
from utopia.monte_carlo.montecarlo_analysis_paper import run_mc_analysis_paper, set_emission, sim_to_dataframe, reshape_mc_results
from utopia.monte_carlo.monte_carlo_helpers import *
from utopia.utopia import utopiaModel
import numpy as np
import scipy.stats as st
import pandas as pd
# Out:
# c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\dvars_sensitivity.py:18: UserWarning: Consider installing numba for better performance
#   warn("Consider installing numba for better performance", UserWarning)

# %% [markdown]
# ### Load the UTOPIA's default configuration parameters

# %%
data_data = utopiaModel.load_json_file("data/default_data.json")
config_data = utopiaModel.load_json_file("data/default_config.json")

# %% [markdown]
# ### Define the parameter distributions for the Monte Carlo simulation.

# %% [markdown]
# Transform the discrete distributions to continuous distributions for compatibility with the current montecarlo function

# %%
import numpy as np
# To reproduce Rakesh results, use these following discrete values to then generate distributions (lognormal and uniform) from which to sample:

# Plastic density (mpdensity): [900, 1100, 1500] kg/m³ 
# Fragmentation style (FI): [0, 0.3, 0.5, 0.7, 1.0] - ranging from more erosive to more explosive fragmentation 
# Discorporation half time (thalf_deg): [316,1000,10000, 31600, 100000] days 
# Fragmentation timescale (thalf_frag): [10, 31.6, 100, 316] days
# your discrete support values

vals_density = np.array([900, 1100, 1500])
vals_FI = np.array([0, 0.3, 0.5, 0.7, 1.0])
vals_deg = np.array([316, 1000, 10000, 31600, 100000])
vals_frag = np.array([10, 31.6, 100, 316])

def lognorm_params_from_values(values, sigma):
    """
    Return (s, scale) for scipy.stats.lognorm given target values.
    sigma = shape parameter (spread in log space).
    We center the lognormal at the geometric mean of the values.
    """
    mu = np.mean(np.log(values))  # geometric mean in log-space
    scale = np.exp(mu - (sigma**2) / 2)
    return sigma, scale

# choose sigma to control spread (tune manually!)
s_deg, scale_deg = lognorm_params_from_values(vals_deg, sigma=0.5)
s_frag, scale_frag = lognorm_params_from_values(vals_frag, sigma=0.8)
s_density, scale_density = lognorm_params_from_values(vals_density, sigma=0.1)
s_FI, scale_FI = lognorm_params_from_values(vals_FI[vals_FI > 0], sigma=0.5)  # avoid zero for lognorm

param_distributions = {
    "MPdensity_kg_m3": ("lognorm", {"s": s_density, "scale": scale_density}),
    "FI": ("uniform", {"loc": 0.0, "scale": 1.0}),
    "t_half_deg_free": ("lognorm", {"s": s_deg, "scale": scale_deg}),
    "t_frag_gen_FreeSurfaceWater": ("lognorm", {"s": s_frag, "scale": scale_frag})
}

# %%
# Visualise the distributions by plotting

for psrsm in param_distributions:
    plot_distribution_from_dict(psrsm, param_distributions)

# %%
# Recent studies have challenged the density of biofilm used here (1388 kg m-3) as being too high. see e.g. # https://doi.org/10.1186/s43591-024-00098-2 
# Consider testing chnages in biofouling density

# %%
# Set emission scenarios to run that are compatible for comparison with observations data from Kooi et al.

##############################################
# DEFINE ARTICLE -> EMISSION SCENARIOS
##############################################

overlay_emission_scenarios = {
    "Sea Sediment | Bergmann":["Ocean_Surface_Water","Coast_Surface_Water","Coast_Column_Water"],
    "Sea Surface all | Cai":["Surface_Freshwater","Coast_Surface_Water","Impacted_Soil_Surface"],
    "Sea Surface Fragments | Enders":["Ocean_Surface_Water","Coast_Surface_Water"],
    "Sea Surface Fibers | Enders":["Ocean_Surface_Water","Coast_Surface_Water"],
    "Fragments in water | Eo":["Impacted_Soil_Surface","Surface_Freshwater"],
    "Fibers in water | Eo":["Impacted_Soil_Surface","Surface_Freshwater"],
    "Fragments in sediment | Eo":["Impacted_Soil_Surface","Surface_Freshwater"],
    "Fibers in sediment | Eo":["Impacted_Soil_Surface","Surface_Freshwater"],
    "Sea Surface all | Erni-Cassola":["Coast_Surface_Water","Impacted_Soil_Surface"],
    "Fresh water sediments | Imhof":["Surface_Freshwater","Impacted_Soil_Surface"],
    "Sea Surface all | Isobe L1":["Surface_Freshwater","Coast_Surface_Water"],
    "Sea Surface all | Isobe L2":["Surface_Freshwater","Coast_Surface_Water"],
    "Sea Surface all | Isobe L3":["Surface_Freshwater","Coast_Surface_Water"],
    "Sea Surface all | Isobe L4":["Surface_Freshwater","Coast_Surface_Water"],
    "FP all | Scheurer":["Impacted_Soil_Surface"],
    "Sea Surface Fragments | Song":["Impacted_Soil_Surface","Surface_Freshwater"],
    "Sea Surface Fibers | Song":["Impacted_Soil_Surface","Surface_Freshwater"],
    "Sea Surface all | Zhang":["Coast_Surface_Water","Surface_Freshwater"]}
    
    
    
    
# DEFINE ARTICLE->COMPARTMENTS MAPPING
#############################################
overlay_compartments_mapping = {
    "Sea Sediment | Bergmann": ["Sediment_Coast", "Sediment_Ocean"],
    "Sea Surface all | Cai": ["Coast_Surface_Water", "Ocean_Surface_Water"],
    "Sea Surface Fragments | Enders": ["Coast_Surface_Water", "Ocean_Surface_Water"],
    "Sea Surface Fibers | Enders": ["Coast_Surface_Water", "Ocean_Surface_Water"],
    "Fragments in water | Eo": ["Bulk_Freshwater", "Surface_Freshwater"],
    "Fibers in water | Eo": ["Bulk_Freshwater", "Surface_Freshwater"],
    "Fragments in sediment | Eo": ["Sediment_Ocean", "Sediment_Coast", "Beaches_Deep_Soil","Beaches_Soil_Surface", "Sediment_Freshwater"],
    "Fibers in sediment | Eo": ["Sediment_Ocean", "Sediment_Coast", "Beaches_Deep_Soil",
    "Beaches_Soil_Surface", "Sediment_Freshwater"],
    "Sea Surface all | Erni-Cassola": ["Coast_Surface_Water", "Ocean_Surface_Water"],
    "Fresh water sediments | Imhof": ["Bulk_Freshwater", "Surface_Freshwater"],
    "Sea Surface all | Isobe L1": ["Coast_Surface_Water", "Ocean_Surface_Water"], 
    "Sea Surface all | Isobe L2": ["Coast_Surface_Water", "Ocean_Surface_Water"], 
    "Sea Surface all | Isobe L3": ["Coast_Surface_Water", "Ocean_Surface_Water"],
    "Sea Surface all | Isobe L4": ["Coast_Surface_Water", "Ocean_Surface_Water"],
    "FP all | Scheurer": ["Coast_Surface_Water", "Ocean_Surface_Water"], 
    "Sea Surface Fragments | Song": ["Coast_Surface_Water", "Ocean_Surface_Water"],
    "Sea Surface Fibers | Song": ["Coast_Surface_Water", "Ocean_Surface_Water"],
    "Sea Surface all | Zhang": ["Coast_Surface_Water", "Ocean_Surface_Water"]
}

# NOTE! Maybe the mapping for the FP all | Scheurer study has to be revisited. Samples were collected in floodplain soils, so the impacted_soil_surface compartment might be more appropriate. Since the model does not simulate floodplain soils as a separate compartment.?

# %%
# Set emission scenarios according to the mapping defined above to the run the model for each parameter combination using the Monte Carlo framework and perform the comparison with the observed data according to mapping.

# %% [markdown]
# Test difference in results if run with distributions or single values for the parameters for one article

# %%
art= "Sea Surface Fibers | Song"
print(f"Running Monte Carlo analysis for article: {art}")
# Out:
# Running Monte Carlo analysis for article: Sea Surface Fibers | Song

# %%
MC_simulations_results=[]
for comp in overlay_emission_scenarios[art]:
    # Set emissions to that compartment and include it in base_data file
    data_data["emiss_dict_g_s"]= set_emission(data_data["emiss_dict_g_s"].copy(), comp, "e", 100)
    
    
    #Run Monte Carlo analysis for each emission scenario and targer compartment
    for comp_T in overlay_compartments_mapping[art]:
        emission_comp=comp
        target_comp=comp_T
        sim= run_mc_analysis_paper(
        base_config=config_data,
        base_data=data_data,
        param_distributions=param_distributions,
        n_cases=20,art=art,emission_comp=emission_comp,target_comp=target_comp
    )
    
        # Convert sim results to dataframe
        df_MC_results = sim_to_dataframe(sim)
        
        
        MC_simulations_results.append(df_MC_results)
MC_simulations_results = pd.concat(MC_simulations_results, ignore_index=True)
# Out:
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 20/20 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 20/20 [00:00<00:00, 3998.76 cases/s]
# Running cases: 100%|██████████| 20/20 [00:44<00:00,  2.21s/ cases]
# Postprocessing cases: 100%|██████████| 20/20 [00:00<00:00, 2868.88 cases/s]
# Simulation complete! Runtime: 0:00:44.331890
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 20/20 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 20/20 [00:00<?, ? cases/s]
# Running cases: 100%|██████████| 20/20 [00:43<00:00,  2.18s/ cases]
# Postprocessing cases: 100%|██████████| 20/20 [00:00<?, ? cases/s]
# Simulation complete! Runtime: 0:00:43.646448
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 20/20 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 20/20 [00:00<00:00, 6674.05 cases/s]
# Running cases: 100%|██████████| 20/20 [00:44<00:00,  2.21s/ cases]
# Postprocessing cases: 100%|██████████| 20/20 [00:00<?, ? cases/s]
# Simulation complete! Runtime: 0:00:44.222109
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 20/20 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 20/20 [00:00<00:00, 1451.09 cases/s]
# Running cases: 100%|██████████| 20/20 [00:47<00:00,  2.39s/ cases]
# Postprocessing cases: 100%|██████████| 20/20 [00:00<00:00, 2905.55 cases/s]
# Simulation complete! Runtime: 0:00:47.853829

# %%
MC_simulations_results
# Out:
#     MPdensity_kg_m3        FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater  \
# 0       1223.294660  0.054891      6510.335737                    18.298327
# 1       1027.531967  0.740818      4154.920691                    47.156730
# 2       1112.195170  0.330629     14492.228790                    37.840555
# 3       1142.043586  0.902573      3158.382174                    79.694563
# 4       1183.945885  0.387262      4865.625691                   162.674424
# ..              ...       ...              ...                          ...
# 75      1266.860208  0.753409      4509.321025                    33.637734
# 76      1249.323720  0.486019      8102.054838                    54.219944
# 77      1052.671922  0.811533      3073.415520                    14.554329
# 78      1128.872678  0.151413      6580.927247                   257.631749
# 79      1161.652019  0.583647      5394.382498                    25.560461
#
#     Spearman_r  Spearman_p  Pass_Spearman      RMSE   R_squared  Model_slope  \
# 0         -1.0         0.0           True  3.617426 -145.545986    -4.123701
# 1         -1.0         0.0           True  3.117036 -107.807371    -4.243710
# 2         -1.0         0.0           True  3.853713 -165.315735    -4.487132
# 3         -1.0         0.0           True  3.318206 -122.305151    -4.252304
# 4         -1.0         0.0           True  3.721413 -154.092331    -4.185854
# ..         ...         ...            ...       ...         ...          ...
# 75        -1.0         0.0           True  3.273275 -118.988525    -3.749644
# 76        -1.0         0.0           True  3.803519 -161.011476    -3.900486
# 77        -1.0         0.0           True  3.094489 -106.238951    -3.741153
# 78         NaN         NaN          False       NaN         NaN          NaN
# 79        -1.0         0.0           True  3.615781 -145.412750    -3.965506
#
#     Model_intercept   Target_compartment   Emission_compartment
# 0          8.340912  Coast_Surface_Water  Impacted_Soil_Surface
# 1          9.180010  Coast_Surface_Water  Impacted_Soil_Surface
# 2          9.108049  Coast_Surface_Water  Impacted_Soil_Surface
# 3          8.999780  Coast_Surface_Water  Impacted_Soil_Surface
# 4          8.407845  Coast_Surface_Water  Impacted_Soil_Surface
# ..              ...                  ...                    ...
# 75         7.653627  Ocean_Surface_Water     Surface_Freshwater
# 76         7.535851  Ocean_Surface_Water     Surface_Freshwater
# 77         7.810706  Ocean_Surface_Water     Surface_Freshwater
# 78              NaN  Ocean_Surface_Water     Surface_Freshwater
# 79         7.904944  Ocean_Surface_Water     Surface_Freshwater
#
# [80 rows x 13 columns]

# %%
#Tidy dataframe

input_params=["MPdensity_kg_m3", "FI", "t_half_deg_free", "t_frag_gen_FreeSurfaceWater"]
tidy_mc_results=reshape_mc_results(MC_simulations_results, input_params, art)
tidy_mc_results
# Out:
#     Case           Observed_dataset   Emission_Compartment  \
# 0      0  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 1      1  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 2      2  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 3      3  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 4      4  Sea Surface Fibers | Song  Impacted_Soil_Surface
# ..   ...                        ...                    ...
# 75    75  Sea Surface Fibers | Song     Surface_Freshwater
# 76    76  Sea Surface Fibers | Song     Surface_Freshwater
# 77    77  Sea Surface Fibers | Song     Surface_Freshwater
# 78    78  Sea Surface Fibers | Song     Surface_Freshwater
# 79    79  Sea Surface Fibers | Song     Surface_Freshwater
#
#      Target_Compartment      RMSE          R2     Slope  Spearman_r  \
# 0   Coast_Surface_Water  3.617426 -145.545986 -4.123701        -1.0
# 1   Coast_Surface_Water  3.117036 -107.807371 -4.243710        -1.0
# 2   Coast_Surface_Water  3.853713 -165.315735 -4.487132        -1.0
# 3   Coast_Surface_Water  3.318206 -122.305151 -4.252304        -1.0
# 4   Coast_Surface_Water  3.721413 -154.092331 -4.185854        -1.0
# ..                  ...       ...         ...       ...         ...
# 75  Ocean_Surface_Water  3.273275 -118.988525 -3.749644        -1.0
# 76  Ocean_Surface_Water  3.803519 -161.011476 -3.900486        -1.0
# 77  Ocean_Surface_Water  3.094489 -106.238951 -3.741153        -1.0
# 78  Ocean_Surface_Water       NaN         NaN       NaN         NaN
# 79  Ocean_Surface_Water  3.615781 -145.412750 -3.965506        -1.0
#
#     Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
# 0            True      1223.294660  0.054891      6510.335737
# 1            True      1027.531967  0.740818      4154.920691
# 2            True      1112.195170  0.330629     14492.228790
# 3            True      1142.043586  0.902573      3158.382174
# 4            True      1183.945885  0.387262      4865.625691
# ..            ...              ...       ...              ...
# 75           True      1266.860208  0.753409      4509.321025
# 76           True      1249.323720  0.486019      8102.054838
# 77           True      1052.671922  0.811533      3073.415520
# 78          False      1128.872678  0.151413      6580.927247
# 79           True      1161.652019  0.583647      5394.382498
#
#     t_frag_gen_FreeSurfaceWater
# 0                     18.298327
# 1                     47.156730
# 2                     37.840555
# 3                     79.694563
# 4                    162.674424
# ..                          ...
# 75                    33.637734
# 76                    54.219944
# 77                    14.554329
# 78                   257.631749
# 79                    25.560461
#
# [80 rows x 13 columns]

# %%
# Sort ascending by RMSE (best fits first)
results_sorted_art = tidy_mc_results.sort_values("RMSE", ascending=True)

# Keep e.g. top 20 best-fitting combinations
top_results_art = results_sorted_art.head(20)

# %%
top_results_art
# Out:
#     Case           Observed_dataset   Emission_Compartment  \
# 66    66  Sea Surface Fibers | Song     Surface_Freshwater
# 46    46  Sea Surface Fibers | Song     Surface_Freshwater
# 41    41  Sea Surface Fibers | Song     Surface_Freshwater
# 43    43  Sea Surface Fibers | Song     Surface_Freshwater
# 26    26  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 29    29  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 45    45  Sea Surface Fibers | Song     Surface_Freshwater
# 57    57  Sea Surface Fibers | Song     Surface_Freshwater
# 9      9  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 55    55  Sea Surface Fibers | Song     Surface_Freshwater
# 6      6  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 51    51  Sea Surface Fibers | Song     Surface_Freshwater
# 61    61  Sea Surface Fibers | Song     Surface_Freshwater
# 53    53  Sea Surface Fibers | Song     Surface_Freshwater
# 59    59  Sea Surface Fibers | Song     Surface_Freshwater
# 47    47  Sea Surface Fibers | Song     Surface_Freshwater
# 63    63  Sea Surface Fibers | Song     Surface_Freshwater
# 21    21  Sea Surface Fibers | Song  Impacted_Soil_Surface
# 77    77  Sea Surface Fibers | Song     Surface_Freshwater
# 65    65  Sea Surface Fibers | Song     Surface_Freshwater
#
#      Target_Compartment      RMSE          R2     Slope  Spearman_r  \
# 66  Ocean_Surface_Water  0.242450    0.341708 -1.260351        -1.0
# 46  Coast_Surface_Water  0.274691    0.154986 -0.926349        -1.0
# 41  Coast_Surface_Water  0.860534   -7.292976 -1.706021        -1.0
# 43  Coast_Surface_Water  1.113318  -12.880744 -1.826492        -1.0
# 26  Ocean_Surface_Water  1.370770  -20.042801 -2.718896        -1.0
# 29  Ocean_Surface_Water  1.421666  -21.634433 -2.524126        -1.0
# 45  Coast_Surface_Water  1.505585  -24.385485 -2.318049        -1.0
# 57  Coast_Surface_Water  1.528237  -25.155067 -2.302899        -1.0
# 9   Coast_Surface_Water  1.560425  -26.268458 -2.624976        -1.0
# 55  Coast_Surface_Water  1.621353  -28.439458 -2.255539        -1.0
# 6   Coast_Surface_Water  1.633334  -28.876149 -2.875577        -1.0
# 51  Coast_Surface_Water  1.672405  -30.322576 -2.251910        -1.0
# 61  Ocean_Surface_Water  1.872917  -38.283652 -2.794831        -1.0
# 53  Coast_Surface_Water  1.900332  -39.442079 -2.425207        -1.0
# 59  Coast_Surface_Water  1.958618  -41.960977 -2.471399        -1.0
# 47  Coast_Surface_Water  2.249846  -55.686550 -2.733908        -1.0
# 63  Ocean_Surface_Water  2.765494  -84.648560 -3.319479        -1.0
# 21  Ocean_Surface_Water  2.941175  -95.876004 -4.101251        -1.0
# 77  Ocean_Surface_Water  3.094489 -106.238951 -3.741153        -1.0
# 65  Ocean_Surface_Water  3.114228 -107.611381 -3.781488        -1.0
#
#     Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
# 66           True       938.199911  0.224775      1827.090958
# 46           True       938.199911  0.224775      1827.090958
# 41           True      1027.531967  0.740818      4154.920691
# 43           True      1142.043586  0.902573      3158.382174
# 26           True       938.199911  0.224775      1827.090958
# 29           True      1011.054694  0.966201      8317.906191
# 45           True      1067.147583  0.814583      7649.971822
# 57           True      1052.671922  0.811533      3073.415520
# 9            True      1011.054694  0.966201      8317.906191
# 55           True      1266.860208  0.753409      4509.321025
# 6            True       938.199911  0.224775      1827.090958
# 51           True      1193.888212  0.679468      7014.614289
# 61           True      1027.531967  0.740818      4154.920691
# 53           True      1121.813351  0.603366      3615.677398
# 59           True      1161.652019  0.583647      5394.382498
# 47           True      1302.585757  0.539578      9481.499850
# 63           True      1142.043586  0.902573      3158.382174
# 21           True      1027.531967  0.740818      4154.920691
# 77           True      1052.671922  0.811533      3073.415520
# 65           True      1067.147583  0.814583      7649.971822
#
#     t_frag_gen_FreeSurfaceWater
# 66                    58.014555
# 46                    58.014555
# 41                    47.156730
# 43                    79.694563
# 26                    58.014555
# 29                   110.332414
# 45                    27.484251
# 57                    14.554329
# 9                    110.332414
# 55                    33.637734
# 6                     58.014555
# 51                    66.504082
# 61                    47.156730
# 53                    22.326528
# 59                    25.560461
# 47                    12.343862
# 63                    79.694563
# 21                    47.156730
# 77                    14.554329
# 65                    27.484251

# %%
from utopia.monte_carlo.montecarlo_analysis_paper import run_and_plot_top_results
run_and_plot_top_results(top_results_art[0:2],data_data, config_data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap for the top results
corr = top_results_art[0:10][["RMSE", "R2", "Slope", "MPdensity_kg_m3", "FI", "t_half_deg_free", "t_frag_gen_FreeSurfaceWater"]].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation matrix (Top 10 best fits)")
plt.show()

# %%
# Pair-wise relationships for the top results
sns.pairplot(
    top_results_art,
    vars=["MPdensity_kg_m3", "FI", "t_half_deg_free", "t_frag_gen_FreeSurfaceWater","RMSE"],
    hue="Target_Compartment",
    corner=True
)
plt.suptitle("Parameter relationships for best-fitting runs", y=1.02)
plt.show()

# %%
# Pearson & Spearman correlation between Density and FI for all results

# Pearson tests linear correlation.

# Spearman tests monotonic correlation (rank-based, robust to nonlinearities).

# If p < 0.05, the correlation is statistically significant.

from scipy.stats import pearsonr, spearmanr

x = top_results_art["MPdensity_kg_m3"]
y = top_results_art["FI"]

pearson_corr, pearson_p = pearsonr(x, y)
spearman_corr, spearman_p = spearmanr(x, y)

print(f"Pearson r = {pearson_corr:.3f}, p = {pearson_p:.3e}")
print(f"Spearman ρ = {spearman_corr:.3f}, p = {spearman_p:.3e}")

import seaborn as sns
import matplotlib.pyplot as plt

sns.lmplot(
    data=top_results_art, 
    x="MPdensity_kg_m3", 
    y="FI", 
    #hue="Target_Compartment", 
    height=6, aspect=1.2,
    scatter_kws={"alpha": 0.7}
)
plt.title("Density vs FI (with regression fits)")
plt.show()
# Out:
# Pearson r = 0.488, p = 1.521e-01
# Spearman ρ = 0.425, p = 2.208e-01

# %%
# Run the Monte Carlo analysis with the specified parameters distributions and number of cases for specified emission scenarios related to the obsserved data from articles in the list.

all_results = [] 

# Run the Monte Carlo analysis for each article and emission scenario
for art in overlay_emission_scenarios: 
    for comp in overlay_emission_scenarios[art]:
        # Set emissions to that compartment and include it in base_data file
        data_data["emiss_dict_g_s"]= set_emission(data_data["emiss_dict_g_s"].copy(), comp, "e", 100)
        
        #Run Monte Carlo analysis for each emission scenario and target compartment
        for comp_T in overlay_compartments_mapping[art]:
            emission_comp=comp
            target_comp=comp_T
            sim= run_mc_analysis_paper(
            base_config=config_data,
            base_data=data_data,
            param_distributions=param_distributions,
            n_cases=100,art=art,emission_comp=emission_comp,target_comp=target_comp
        )
        
        
            # Convert sim results to dataframe
            df_MC_results = sim_to_dataframe(sim)
            #Tidy dataframe
            input_params=["MPdensity_kg_m3", "FI", "t_half_deg_free", "t_frag_gen_FreeSurfaceWater"] # "overall_persistence_mass"...
            tidy_mc_results_df=reshape_mc_results(df_MC_results, input_params, art)
            
            all_results.append(tidy_mc_results_df)
        
        

results_df = pd.concat(all_results, ignore_index=True)
# Out:
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 10037.58 cases/s]
# Running cases:   6%|▌         | 6/100 [00:14<03:58,  2.54s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:   9%|▉         | 9/100 [00:22<03:53,  2.56s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [01:02<04:01,  3.10s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [01:10<03:37,  2.91s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  30%|███       | 30/100 [01:24<03:12,  2.75s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  33%|███▎      | 33/100 [01:31<02:49,  2.53s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [01:43<02:30,  2.43s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [01:50<02:21,  2.39s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  54%|█████▍    | 54/100 [02:20<01:43,  2.24s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [02:27<01:38,  2.30s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [03:02<01:16,  2.54s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  73%|███████▎  | 73/100 [03:09<01:07,  2.49s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [03:43<00:35,  2.50s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [03:50<00:27,  2.51s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  97%|█████████▋| 97/100 [04:11<00:07,  2.61s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [04:19<00:00,  2.59s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7687.79 cases/s]
# Simulation complete! Runtime: 0:04:19.456962
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8387.10 cases/s]
# Running cases:   6%|▌         | 6/100 [00:16<04:26,  2.84s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:   9%|▉         | 9/100 [00:23<03:48,  2.51s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [00:55<03:00,  2.32s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [01:01<02:51,  2.29s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  30%|███       | 30/100 [01:13<02:35,  2.22s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  33%|███▎      | 33/100 [01:19<02:29,  2.23s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [01:31<02:32,  2.46s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [01:39<02:31,  2.58s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  54%|█████▍    | 54/100 [02:13<01:50,  2.40s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [02:20<01:37,  2.28s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [02:50<01:08,  2.28s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  73%|███████▎  | 73/100 [02:56<00:59,  2.21s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [03:26<00:32,  2.31s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [03:32<00:24,  2.24s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  97%|█████████▋| 97/100 [03:50<00:06,  2.28s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [03:57<00:00,  2.37s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 13301.32 cases/s]
# Simulation complete! Runtime: 0:03:57.309885
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8336.09 cases/s]
# Running cases:   6%|▌         | 6/100 [00:13<03:32,  2.26s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:   9%|▉         | 9/100 [00:20<03:21,  2.22s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [00:49<03:02,  2.34s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [00:56<02:55,  2.34s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  30%|███       | 30/100 [01:09<02:55,  2.51s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  33%|███▎      | 33/100 [01:17<02:47,  2.51s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [01:29<02:26,  2.37s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [01:36<02:15,  2.30s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  54%|█████▍    | 54/100 [02:05<01:44,  2.27s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [02:12<01:42,  2.38s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [02:45<01:30,  3.01s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  73%|███████▎  | 73/100 [02:56<01:29,  3.31s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [03:29<00:32,  2.35s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [03:36<00:25,  2.36s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  97%|█████████▋| 97/100 [03:55<00:06,  2.30s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [04:02<00:00,  2.42s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 10773.41 cases/s]
# Simulation complete! Runtime: 0:04:02.361677
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 11917.33 cases/s]
# Running cases:   6%|▌         | 6/100 [00:13<03:33,  2.27s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:   9%|▉         | 9/100 [00:21<03:35,  2.37s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [00:49<02:50,  2.19s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [00:56<02:43,  2.18s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  30%|███       | 30/100 [01:07<02:38,  2.26s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  33%|███▎      | 33/100 [01:13<02:25,  2.18s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [01:26<02:37,  2.54s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [01:34<02:36,  2.66s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  54%|█████▍    | 54/100 [02:06<01:48,  2.36s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [02:13<01:42,  2.38s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [02:42<01:03,  2.13s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  73%|███████▎  | 73/100 [02:49<01:00,  2.23s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [03:18<00:30,  2.19s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [03:25<00:24,  2.23s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  97%|█████████▋| 97/100 [03:45<00:07,  2.57s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [03:53<00:00,  2.34s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6617.50 cases/s]
# Simulation complete! Runtime: 0:03:53.761866
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 9466.25 cases/s]
# Running cases:   6%|▌         | 6/100 [00:15<04:07,  2.63s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:   9%|▉         | 9/100 [00:23<03:42,  2.45s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [00:55<03:16,  2.52s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [01:03<03:11,  2.55s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  30%|███       | 30/100 [01:15<02:55,  2.50s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  33%|███▎      | 33/100 [01:23<02:43,  2.44s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [01:35<02:28,  2.40s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [01:42<02:22,  2.41s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  54%|█████▍    | 54/100 [02:13<01:57,  2.55s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [02:21<01:53,  2.63s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [02:55<01:20,  2.68s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  73%|███████▎  | 73/100 [03:04<01:12,  2.70s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [03:38<00:37,  2.68s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [03:46<00:29,  2.72s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  97%|█████████▋| 97/100 [04:07<00:07,  2.57s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [04:15<00:00,  2.55s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6392.78 cases/s]
# Simulation complete! Runtime: 0:04:15.380131
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 5342.86 cases/s]
# Running cases:   6%|▌         | 6/100 [00:15<04:05,  2.61s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:   9%|▉         | 9/100 [00:23<04:00,  2.64s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [00:55<03:12,  2.47s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [01:03<03:13,  2.59s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  30%|███       | 30/100 [01:17<03:09,  2.71s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  33%|███▎      | 33/100 [01:25<02:58,  2.66s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [01:38<02:41,  2.61s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [01:45<02:34,  2.62s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  54%|█████▍    | 54/100 [02:20<02:00,  2.62s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [02:28<01:53,  2.64s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [03:02<01:16,  2.56s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  73%|███████▎  | 73/100 [03:09<01:10,  2.61s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [03:44<00:37,  2.66s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [03:52<00:29,  2.67s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  97%|█████████▋| 97/100 [04:13<00:07,  2.55s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [04:20<00:00,  2.61s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7060.88 cases/s]
# Simulation complete! Runtime: 0:04:21.043602
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6212.31 cases/s]
# Running cases: 100%|██████████| 100/100 [04:18<00:00,  2.59s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7470.22 cases/s]
# Simulation complete! Runtime: 0:04:18.831870
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7157.52 cases/s]
# Running cases: 100%|██████████| 100/100 [04:19<00:00,  2.59s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 25536.10 cases/s]
# Simulation complete! Runtime: 0:04:19.210266
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 5130.21 cases/s]
# Running cases: 100%|██████████| 100/100 [04:18<00:00,  2.59s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 5431.84 cases/s]
# Simulation complete! Runtime: 0:04:18.662856
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 9671.87 cases/s]
# Running cases: 100%|██████████| 100/100 [04:23<00:00,  2.63s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7126.14 cases/s]
# Simulation complete! Runtime: 0:04:23.507424
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8590.66 cases/s]
# Running cases: 100%|██████████| 100/100 [04:26<00:00,  2.67s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 24998.83 cases/s]
# Simulation complete! Runtime: 0:04:26.758737
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 10504.93 cases/s]
# Running cases: 100%|██████████| 100/100 [04:26<00:00,  2.67s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 5124.69 cases/s]
# Simulation complete! Runtime: 0:04:26.798200
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7987.78 cases/s]
# Running cases: 100%|██████████| 100/100 [04:27<00:00,  2.67s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 12504.63 cases/s]
# Simulation complete! Runtime: 0:04:27.077325
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 39684.97 cases/s]
# Running cases: 100%|██████████| 100/100 [1:03:34<00:00, 38.14s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 11128.43 cases/s]
# Simulation complete! Runtime: 1:03:34.311611
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 10080.77 cases/s]
# Running cases: 100%|██████████| 100/100 [03:32<00:00,  2.12s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6915.13 cases/s]
# Simulation complete! Runtime: 0:03:32.291466
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8712.18 cases/s]
# Running cases: 100%|██████████| 100/100 [03:35<00:00,  2.16s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7817.17 cases/s]
# Simulation complete! Runtime: 0:03:35.575812
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7618.67 cases/s]
# Running cases: 100%|██████████| 100/100 [03:45<00:00,  2.26s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8247.90 cases/s]
# Simulation complete! Runtime: 0:03:45.582368
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8855.28 cases/s]
# Running cases: 100%|██████████| 100/100 [03:27<00:00,  2.07s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<?, ? cases/s]
# Simulation complete! Runtime: 0:03:27.504247
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 9989.77 cases/s]
# Running cases: 100%|██████████| 100/100 [03:36<00:00,  2.17s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<?, ? cases/s]
# Simulation complete! Runtime: 0:03:36.753011
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 11101.62 cases/s]
# Running cases: 100%|██████████| 100/100 [03:35<00:00,  2.16s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 29002.24 cases/s]
# Simulation complete! Runtime: 0:03:35.947950
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 9990.48 cases/s]
# Running cases: 100%|██████████| 100/100 [04:20<00:00,  2.61s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 4300.53 cases/s]
# Simulation complete! Runtime: 0:04:20.840305
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 5847.02 cases/s]
# Running cases: 100%|██████████| 100/100 [04:17<00:00,  2.57s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8529.52 cases/s]
# Simulation complete! Runtime: 0:04:17.174005
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 7950.99 cases/s]
# Running cases: 100%|██████████| 100/100 [04:23<00:00,  2.64s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 53911.36 cases/s]
# Simulation complete! Runtime: 0:04:23.838250
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 99015.68 cases/s]
# Running cases: 100%|██████████| 100/100 [04:26<00:00,  2.67s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 11323.10 cases/s]
# Simulation complete! Runtime: 0:04:26.683139
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6695.14 cases/s]
# Running cases: 100%|██████████| 100/100 [04:21<00:00,  2.61s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 12350.72 cases/s]
# Simulation complete! Runtime: 0:04:21.450314
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8701.15 cases/s]
# Running cases: 100%|██████████| 100/100 [04:24<00:00,  2.65s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6632.99 cases/s]
# Simulation complete! Runtime: 0:04:24.925985
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8425.51 cases/s]
# Running cases: 100%|██████████| 100/100 [03:50<00:00,  2.31s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6557.39 cases/s]
# Simulation complete! Runtime: 0:03:51.012719
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 11326.77 cases/s]
# Running cases: 100%|██████████| 100/100 [3:46:29<00:00, 135.89s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 2989.04 cases/s]
# Simulation complete! Runtime: 3:46:29.369416
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 3583.74 cases/s]
# Running cases:   6%|▌         | 6/100 [00:44<11:23,  7.27s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:   9%|▉         | 9/100 [01:04<10:24,  6.86s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [02:37<09:33,  7.35s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [02:57<08:36,  6.89s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  30%|███       | 30/100 [03:30<07:37,  6.54s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  33%|███▎      | 33/100 [03:39<04:33,  4.09s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [03:52<03:03,  2.96s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [04:01<02:47,  2.83s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  54%|█████▍    | 54/100 [04:36<02:04,  2.71s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [04:44<01:55,  2.67s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [05:20<01:24,  2.83s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  73%|███████▎  | 73/100 [05:28<01:16,  2.82s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [06:03<00:36,  2.63s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [06:11<00:28,  2.60s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  97%|█████████▋| 97/100 [2:27:43<1:29:04, 1781.45s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [2:27:53<00:00, 88.73s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 4709.84 cases/s]
# Simulation complete! Runtime: 2:27:53.437509
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6841.36 cases/s]
# Running cases:   6%|▌         | 6/100 [00:18<04:27,  2.84s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:   9%|▉         | 9/100 [00:27<04:25,  2.92s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [01:09<04:18,  3.31s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [01:19<03:56,  3.16s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  30%|███       | 30/100 [01:34<03:26,  2.96s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  33%|███▎      | 33/100 [01:42<03:13,  2.89s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [01:58<03:08,  3.04s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [02:07<02:58,  3.03s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  54%|█████▍    | 54/100 [02:43<02:08,  2.80s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [02:51<02:00,  2.79s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [1:45:24<14:06, 28.21s/ cases]     c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  73%|███████▎  | 73/100 [1:45:32<05:10, 11.50s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [1:46:08<00:40,  2.90s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [1:46:16<00:31,  2.83s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  97%|█████████▋| 97/100 [1:46:38<00:08,  2.70s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [1:46:47<00:00, 64.07s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 6723.26 cases/s]
# Simulation complete! Runtime: 1:46:47.470379
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 11155.06 cases/s]
# Running cases: 100%|██████████| 100/100 [4:07:04<00:00, 148.25s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 17331.83 cases/s]
# Simulation complete! Runtime: 4:07:05.064792
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 4250.50 cases/s]
# Running cases: 100%|██████████| 100/100 [45:46<00:00, 27.46s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 13695.69 cases/s]
# Simulation complete! Runtime: 0:45:46.156818
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 4976.75 cases/s]
# Running cases:   6%|▌         | 6/100 [00:17<04:33,  2.91s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  22%|██▏       | 22/100 [01:01<03:33,  2.74s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  25%|██▌       | 25/100 [01:09<03:24,  2.73s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  38%|███▊      | 38/100 [1:30:03<3:16:04, 189.74s/ cases]  c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  41%|████      | 41/100 [1:30:12<1:05:46, 66.90s/ cases] c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  57%|█████▋    | 57/100 [1:30:58<02:17,  3.21s/ cases]  c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  70%|███████   | 70/100 [1:31:35<01:26,  2.87s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  86%|████████▌ | 86/100 [1:32:21<00:39,  2.84s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases:  89%|████████▉ | 89/100 [1:32:29<00:30,  2.74s/ cases]c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Running cases: 100%|██████████| 100/100 [3:13:28<00:00, 116.09s/ cases]
# Postprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 4745.92 cases/s]
# Simulation complete! Runtime: 3:13:28.599977
# Running 'UTOPIA_MC_simulation' Monte Carlo simulation with 100/100 cases...
# Drawing random samples for 4 input variables via the 'sobol_random' method... Done
# Generating cases... Done
# Preprocessing cases: 100%|██████████| 100/100 [00:00<00:00, 8943.46 cases/s]
# Running cases:   0%|          | 0/100 [00:00<?, ? cases/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 15
#      13     emission_comp=comp
#      14     target_comp=comp_T
# ---> 15     sim= run_mc_analysis_paper(
#      16     base_config=config_data,
#      17     base_data=data_data,
#      18     param_distributions=param_distributions,
#      19     n_cases=100,art=art,emission_comp=emission_comp,target_comp=target_comp
#      20 )
#      23     # Convert sim results to dataframe
#      24     df_MC_results = sim_to_dataframe(sim)
#
# File ~\Documents\utopia_package\src\utopia\monte_carlo\montecarlo_analysis_paper.py:270, in run_mc_analysis_paper(base_config, base_data, art, n_cases, emission_comp, param_distributions, target_comp)
#     267     sim.addInVar(param, getattr(st, dist_name), dist_kwargs)
#     269 # Run simulation
# --> 270 sim.runSim()
#     272 # Process results (to be added)
#     274 return sim
#
# File c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\mc_sim.py:397, in Sim.runSim(self, cases)
#     394 cases_downselect = self.downselectCases(cases=cases)
#     395 vprint(self.verbose, f"Running '{self.name}' Monte Carlo simulation with " +
#     396                      f"{len(cases_downselect)}/{self.ncases} cases...", flush=True)
# --> 397 self.runSimWorker(casestogenerate=cases_downselect, casestopreprocess=cases_downselect,
#     398                   casestorun=cases_downselect, casestopostprocess=cases_downselect)
#
# File c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\mc_sim.py:464, in Sim.runSimWorker(self, casestogenerate, casestopreprocess, casestorun, casestopostprocess)
#     462 self.drawVars()
#     463 self.genCases(cases=casestogenerate)
# --> 464 self.executeAllFcns(casestopreprocess=casestopreprocess,
#     465                     casestorun=casestorun,
#     466                     casestopostprocess=casestopostprocess,
#     467                     calledfromrunsim=True)
#     468 self.genOutVars()
#     470 self.endtime = datetime.now()
#
# File c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\mc_sim.py:564, in Sim.executeAllFcns(self, casestopreprocess, casestorun, casestopostprocess, calledfromrunsim)
#     562 if self.singlethreaded:
#     563     self.preProcessCases(cases=casestopreprocess)
# --> 564     self.runCases(cases=casestorun, calledfromrunsim=calledfromrunsim)
#     565     self.postProcessCases(cases=casestopostprocess)
#     566 else:
#
# File c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\mc_sim.py:727, in Sim.runCases(self, cases, calledfromrunsim)
#     725 if case.ncase in cases_downselect:
#     726     case.hasrun = False
# --> 727     case = run_case(self.fcns[SimFunctions.RUN], case,
#     728                     self.debug, self.verbose, self.runsimid)
#     729     runcases.append(case)
#     730     if self.verbose:
#
# File c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\case_runners.py:65, in run_case(runfcn, case, debug, verbose, runsimid)
#      63 try:
#      64     case.starttime = datetime.now()
# ---> 65     case.simrawoutput = runfcn(*get_list(case.siminput))
#      66     case.endtime = datetime.now()
#      67     case.runtime = case.endtime - case.starttime
#
# File ~\Documents\utopia_package\src\utopia\monte_carlo\montecarlo_analysis_paper.py:77, in run_mc_analysis_paper.<locals>.run_fn(inputs)
#      75 processor.estimate_flows()
#      76 processor.generate_flows_dict()
# ---> 77 processor.process_results()
#      79 # Extract results by compartment and include the concentration in mass and number for each compartment in the result dictionary (only used one compartment here as example, to be considered if relevant for all or fix a different mechanism to store these results)
#      81 processor.extract_results_by_compartment()
#
# File ~\Documents\utopia_package\src\utopia\results_processing\process_results.py:71, in ResultsProcessor.process_results(self)
#      67 Results_extended2 = self.addFlows_to_results_df(Results_extended)
#      69 """ Fix input flows dict to results extended dataframe"""
# ---> 71 interactions_pp_df = fillInteractions_fun_OOP_dict(
#      72     self.model.system_particle_object_list,
#      73     self.model.SpeciesList,
#      74     self.surfComp_list,
#      75 )
#      76 # Estimate Pnum_SS (particle number at steady state) for each particle object in the system
#      77 for p in self.model.system_particle_object_list:
#
# File ~\Documents\utopia_package\src\utopia\preprocessing\fill_interactions_dictionaries.py:26, in fillInteractions_fun_OOP_dict(system_particle_object_list, SpeciesList, surfComp_list)
#      19     interactions_df_rows.append(
#      20         interactionProcess_dict(
#      21             sp1, interactions_df, system_particle_object_list, surfComp_list
#      22         )
#      23     )
#      25 # interact3(sp1) for sp1 in interactions_df.index.to_list()]
# ---> 26 array = np.column_stack(
#      27     interactions_df_rows
#      28 )  # vstack it was set as column stack and was wrong!!
#      29 interactions_df_sol = pd.DataFrame(array, index=SpeciesList, columns=SpeciesList)
#      31 return interactions_df_sol.transpose()
#
# File c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\numpy\lib\shape_base.py:648, in column_stack(tup)
#     646 arrays = []
#     647 for v in tup:
# --> 648     arr = asanyarray(v)
#     649     if arr.ndim < 2:
#     650         arr = array(arr, copy=False, subok=True, ndmin=2).T
#
# KeyboardInterrupt:

# %%
all_results
# Out:
# [    Case         Observed_dataset Emission_Compartment Target_Compartment  \
#  0      0  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  1      1  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  2      2  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  3      3  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  4      4  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  ..   ...                      ...                  ...                ...
#  95    95  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  96    96  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  97    97  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  98    98  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#  99    99  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Coast
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN        NaN       NaN         NaN          False      1223.294660
#  1   1.141678 -20.352664 -1.616065        -1.0           True      1027.531967
#  2        NaN        NaN       NaN         NaN          False      1112.195170
#  3   1.313006 -27.242186 -1.300789        -1.0           True      1142.043586
#  4        NaN        NaN       NaN         NaN          False      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  1.305325 -26.912733 -1.574649        -1.0           True      1231.166859
#  96       NaN        NaN       NaN         NaN          False      1238.635520
#  97       NaN        NaN       NaN        -1.0           True      1019.089303
#  98  0.768300  -8.669992 -1.737290        -1.0           True      1099.600655
#  99  1.251521 -24.659087 -1.482573        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case         Observed_dataset Emission_Compartment Target_Compartment  \
#  0      0  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  1      1  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  2      2  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  3      3  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  4      4  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  ..   ...                      ...                  ...                ...
#  95    95  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  96    96  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  97    97  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  98    98  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#  99    99  Sea Sediment | Bergmann  Ocean_Surface_Water     Sediment_Ocean
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN        NaN       NaN         NaN          False      1223.294660
#  1   1.153205 -20.786017 -1.707323        -1.0           True      1027.531967
#  2   0.786994  -9.146299 -1.755016        -1.0           True      1112.195170
#  3   1.313950 -27.282804 -1.401943        -1.0           True      1142.043586
#  4        NaN        NaN       NaN         NaN          False      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  1.297937 -26.597660 -1.724252        -1.0           True      1231.166859
#  96  0.775452  -8.850871 -1.689817        -1.0           True      1238.635520
#  97       NaN        NaN       NaN        -1.0           True      1019.089303
#  98  0.774644  -8.830369 -1.867553        -1.0           True      1099.600655
#  99  1.250564 -24.619885 -1.608073        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case         Observed_dataset Emission_Compartment Target_Compartment  \
#  0      0  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  1      1  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  2      2  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  3      3  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  4      4  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  ..   ...                      ...                  ...                ...
#  95    95  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  96    96  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  97    97  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  98    98  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#  99    99  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Coast
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN        NaN       NaN         NaN          False      1223.294660
#  1   1.180818 -21.841824 -1.514300        -1.0           True      1027.531967
#  2        NaN        NaN       NaN         NaN          False      1112.195170
#  3   1.344989 -28.634831 -1.243050        -1.0           True      1142.043586
#  4        NaN        NaN       NaN         NaN          False      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  1.312728 -27.230223 -1.561604        -1.0           True      1231.166859
#  96       NaN        NaN       NaN         NaN          False      1238.635520
#  97       NaN        NaN       NaN        -1.0           True      1019.089303
#  98  0.782662  -9.034920 -1.713398        -1.0           True      1099.600655
#  99  1.269724 -25.410943 -1.451030        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case         Observed_dataset Emission_Compartment Target_Compartment  \
#  0      0  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  1      1  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  2      2  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  3      3  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  4      4  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  ..   ...                      ...                  ...                ...
#  95    95  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  96    96  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  97    97  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  98    98  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#  99    99  Sea Sediment | Bergmann  Coast_Surface_Water     Sediment_Ocean
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN        NaN       NaN         NaN          False      1223.294660
#  1   0.949712 -13.775714 -2.301350        -1.0           True      1027.531967
#  2   0.364540  -1.176981 -2.625884        -1.0           True      1112.195170
#  3   0.860743 -11.137027 -2.281730        -1.0           True      1142.043586
#  4        NaN        NaN       NaN         NaN          False      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  0.874042 -11.514969 -2.567754        -1.0           True      1231.166859
#  96  0.354261  -1.055941 -2.534694        -1.0           True      1238.635520
#  97       NaN        NaN       NaN        -1.0           True      1019.089303
#  98  0.350209  -1.009181 -2.757491        -1.0           True      1099.600655
#  99  0.806552  -9.656879 -2.484938        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case         Observed_dataset Emission_Compartment Target_Compartment  \
#  0      0  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  1      1  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  2      2  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  3      3  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  4      4  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  ..   ...                      ...                  ...                ...
#  95    95  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  96    96  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  97    97  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  98    98  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#  99    99  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Coast
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN        NaN       NaN         NaN          False      1223.294660
#  1   1.180797 -21.841024 -1.514272        -1.0           True      1027.531967
#  2        NaN        NaN       NaN         NaN          False      1112.195170
#  3   1.344980 -28.634432 -1.243050        -1.0           True      1142.043586
#  4        NaN        NaN       NaN         NaN          False      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  1.312713 -27.229576 -1.561630        -1.0           True      1231.166859
#  96       NaN        NaN       NaN         NaN          False      1238.635520
#  97       NaN        NaN       NaN        -1.0           True      1019.089303
#  98  0.782659  -9.034839 -1.713403        -1.0           True      1099.600655
#  99  1.269717 -25.410621 -1.451039        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case         Observed_dataset Emission_Compartment Target_Compartment  \
#  0      0  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  1      1  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  2      2  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  3      3  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  4      4  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  ..   ...                      ...                  ...                ...
#  95    95  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  96    96  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  97    97  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  98    98  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#  99    99  Sea Sediment | Bergmann   Coast_Column_Water     Sediment_Ocean
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN        NaN       NaN         NaN          False      1223.294660
#  1   0.948548 -13.739524 -2.309546        -1.0           True      1027.531967
#  2   0.358815  -1.109144 -2.651330        -1.0           True      1112.195170
#  3   0.852470 -10.904830 -2.308048        -1.0           True      1142.043586
#  4   0.294422  -0.420058 -2.488300        -1.0           True      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  0.866108 -11.288788 -2.594914        -1.0           True      1231.166859
#  96  0.347308  -0.976030 -2.561767        -1.0           True      1238.635520
#  97       NaN        NaN       NaN        -1.0           True      1019.089303
#  98  0.345012  -0.949994 -2.782890        -1.0           True      1099.600655
#  99  0.798974  -9.457566 -2.511407        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case       Observed_dataset Emission_Compartment   Target_Compartment  \
#  0      0  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  1      1  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  2      2  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  3      3  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  4      4  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  ..   ...                    ...                  ...                  ...
#  95    95  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  96    96  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  97    97  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  98    98  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#  99    99  Sea Surface all | Cai   Surface_Freshwater  Coast_Surface_Water
#
#          RMSE        R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN       NaN       NaN         NaN          False      1223.294660
#  1   0.367288  0.613385 -1.639589        -1.0           True      1027.531967
#  2        NaN       NaN       NaN         NaN          False      1112.195170
#  3        NaN       NaN       NaN         NaN          False      1142.043586
#  4        NaN       NaN       NaN         NaN          False      1183.945885
#  ..       ...       ...       ...         ...            ...              ...
#  95  0.830668 -0.977524 -2.258183        -1.0           True      1231.166859
#  96       NaN       NaN       NaN         NaN          False      1238.635520
#  97       NaN       NaN       NaN         NaN          False      1019.089303
#  98       NaN       NaN       NaN         NaN          False      1099.600655
#  99  0.772372 -0.709698 -2.065456        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case       Observed_dataset Emission_Compartment   Target_Compartment  \
#  0      0  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  1      1  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  2      2  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  3      3  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  4      4  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  ..   ...                    ...                  ...                  ...
#  95    95  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  96    96  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  97    97  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  98    98  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#  99    99  Sea Surface all | Cai   Surface_Freshwater  Ocean_Surface_Water
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN        NaN       NaN         NaN          False      1223.294660
#  1   1.079109  -2.337312 -2.728782        -1.0           True      1027.531967
#  2   2.734043 -20.422842 -4.004293        -1.0           True      1112.195170
#  3   1.842680  -8.731195 -3.248002        -1.0           True      1142.043586
#  4        NaN        NaN       NaN         NaN          False      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  2.133931 -12.050504 -3.752840        -1.0           True      1231.166859
#  96  2.702728 -19.934906 -3.843504        -1.0           True      1238.635520
#  97       NaN        NaN       NaN         NaN          False      1019.089303
#  98  2.709034 -20.032716 -3.932559        -1.0           True      1099.600655
#  99  2.068951 -11.267805 -3.559036        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case       Observed_dataset Emission_Compartment   Target_Compartment  \
#  0      0  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  1      1  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  2      2  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  3      3  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  4      4  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  ..   ...                    ...                  ...                  ...
#  95    95  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  96    96  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  97    97  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  98    98  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#  99    99  Sea Surface all | Cai  Coast_Surface_Water  Coast_Surface_Water
#
#      RMSE  R2  Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3        FI  \
#  0    NaN NaN    NaN         NaN          False      1223.294660  0.054891
#  1    NaN NaN    NaN         NaN          False      1027.531967  0.740818
#  2    NaN NaN    NaN         NaN          False      1112.195170  0.330629
#  3    NaN NaN    NaN         NaN          False      1142.043586  0.902573
#  4    NaN NaN    NaN         NaN          False      1183.945885  0.387262
#  ..   ...  ..    ...         ...            ...              ...       ...
#  95   NaN NaN    NaN         NaN          False      1231.166859  0.851008
#  96   NaN NaN    NaN         NaN          False      1238.635520  0.233781
#  97   NaN NaN    NaN         NaN          False      1019.089303  0.532990
#  98   NaN NaN    NaN         NaN          False      1099.600655  0.380620
#  99   NaN NaN    NaN         NaN          False      1149.916949  0.823658
#
#      t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0       5884.711542                    30.044884
#  1       2868.534938                    54.291047
#  2      21172.690691                    47.313693
#  3       1849.708321                    75.362682
#  4       3693.020138                   117.716668
#  ..              ...                          ...
#  95      6058.951788                    27.518399
#  96     11352.757679                    45.146966
#  97       993.879397                    81.458540
#  98      7326.505206                    32.499436
#  99      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case       Observed_dataset Emission_Compartment   Target_Compartment  \
#  0      0  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  1      1  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  2      2  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  3      3  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  4      4  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  ..   ...                    ...                  ...                  ...
#  95    95  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  96    96  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  97    97  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  98    98  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#  99    99  Sea Surface all | Cai  Coast_Surface_Water  Ocean_Surface_Water
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0        NaN        NaN       NaN         NaN          False      1223.294660
#  1   0.871451  -1.176469 -2.537056        -1.0           True      1027.531967
#  2   2.656005 -19.217343 -3.866528        -1.0           True      1112.195170
#  3   1.679275  -7.081835 -3.024053        -1.0           True      1142.043586
#  4        NaN        NaN       NaN         NaN          False      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  2.022833 -10.726983 -3.557274        -1.0           True      1231.166859
#  96  2.600629 -18.383104 -3.653654        -1.0           True      1238.635520
#  97       NaN        NaN       NaN         NaN          False      1019.089303
#  98  2.609599 -18.517046 -3.779975        -1.0           True      1099.600655
#  99  1.943727  -9.827718 -3.367621        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case       Observed_dataset   Emission_Compartment   Target_Compartment  \
#  0      0  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  1      1  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  2      2  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  3      3  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  4      4  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  ..   ...                    ...                    ...                  ...
#  95    95  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  96    96  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  97    97  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  98    98  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#  99    99  Sea Surface all | Cai  Impacted_Soil_Surface  Coast_Surface_Water
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0   2.492258 -16.801323 -4.053345        -1.0           True      1223.294660
#  1   1.979556 -10.230577 -4.170501        -1.0           True      1027.531967
#  2   2.631541 -18.846630 -4.457514        -1.0           True      1112.195170
#  3   2.158091 -12.347685 -4.172318        -1.0           True      1142.043586
#  4   2.646512 -19.073091 -4.237836        -1.0           True      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  2.479635 -16.621459 -4.636189        -1.0           True      1231.166859
#  96  2.584131 -18.137944 -4.314974        -1.0           True      1238.635520
#  97  1.412995  -4.722001 -2.929465        -1.0           True      1019.089303
#  98  2.739680 -20.511267 -4.536178        -1.0           True      1099.600655
#  99  2.333157 -14.601073 -4.403126        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case       Observed_dataset   Emission_Compartment   Target_Compartment  \
#  0      0  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  1      1  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  2      2  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  3      3  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  4      4  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  ..   ...                    ...                    ...                  ...
#  95    95  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  96    96  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  97    97  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  98    98  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#  99    99  Sea Surface all | Cai  Impacted_Soil_Surface  Ocean_Surface_Water
#
#          RMSE         R2     Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3  \
#  0   2.446663 -16.155942 -4.008931        -1.0           True      1223.294660
#  1   1.836272  -8.663633 -4.027991        -1.0           True      1027.531967
#  2   2.565132 -17.857578 -4.392890        -1.0           True      1112.195170
#  3   2.098424 -11.619810 -4.115620        -1.0           True      1142.043586
#  4   2.595638 -18.308776 -4.188693        -1.0           True      1183.945885
#  ..       ...        ...       ...         ...            ...              ...
#  95  2.434838 -15.990514 -4.592520        -1.0           True      1231.166859
#  96  2.540326 -17.494615 -4.272061        -1.0           True      1238.635520
#  97  1.350984  -4.230784 -2.899190        -1.0           True      1019.089303
#  98  2.667537 -19.393289 -4.466508        -1.0           True      1099.600655
#  99  2.276128 -13.847718 -4.348130        -1.0           True      1149.916949
#
#            FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0   0.054891      5884.711542                    30.044884
#  1   0.740818      2868.534938                    54.291047
#  2   0.330629     21172.690691                    47.313693
#  3   0.902573      1849.708321                    75.362682
#  4   0.387262      3693.020138                   117.716668
#  ..       ...              ...                          ...
#  95  0.851008      6058.951788                    27.518399
#  96  0.233781     11352.757679                    45.146966
#  97  0.532990       993.879397                    81.458540
#  98  0.380620      7326.505206                    32.499436
#  99  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case                Observed_dataset Emission_Compartment  \
#  0      0  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  1      1  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  2      2  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  3      3  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  4      4  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  ..   ...                             ...                  ...
#  95    95  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  96    96  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  97    97  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  98    98  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  99    99  Sea Surface Fragments | Enders  Ocean_Surface_Water
#
#       Target_Compartment      RMSE        R2     Slope  Spearman_r  \
#  0   Coast_Surface_Water       NaN       NaN       NaN         NaN
#  1   Coast_Surface_Water  0.796065 -1.168924 -1.968295        -1.0
#  2   Coast_Surface_Water       NaN       NaN       NaN         NaN
#  3   Coast_Surface_Water       NaN       NaN       NaN         NaN
#  4   Coast_Surface_Water       NaN       NaN       NaN         NaN
#  ..                  ...       ...       ...       ...         ...
#  95  Coast_Surface_Water  0.551333 -0.040341 -2.310156        -1.0
#  96  Coast_Surface_Water       NaN       NaN       NaN         NaN
#  97  Coast_Surface_Water       NaN       NaN       NaN         NaN
#  98  Coast_Surface_Water       NaN       NaN       NaN         NaN
#  99  Coast_Surface_Water  0.486623  0.189536 -2.204984        -1.0
#
#      Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
#  0           False      1223.294660  0.054891      5884.711542
#  1            True      1027.531967  0.740818      2868.534938
#  2           False      1112.195170  0.330629     21172.690691
#  3           False      1142.043586  0.902573      1849.708321
#  4           False      1183.945885  0.387262      3693.020138
#  ..            ...              ...       ...              ...
#  95           True      1231.166859  0.851008      6058.951788
#  96          False      1238.635520  0.233781     11352.757679
#  97          False      1019.089303  0.532990       993.879397
#  98          False      1099.600655  0.380620      7326.505206
#  99           True      1149.916949  0.823658      3570.610973
#
#      t_frag_gen_FreeSurfaceWater
#  0                     30.044884
#  1                     54.291047
#  2                     47.313693
#  3                     75.362682
#  4                    117.716668
#  ..                          ...
#  95                    27.518399
#  96                    45.146966
#  97                    81.458540
#  98                    32.499436
#  99                    51.807228
#
#  [100 rows x 13 columns],
#      Case                Observed_dataset Emission_Compartment  \
#  0      0  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  1      1  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  2      2  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  3      3  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  4      4  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  ..   ...                             ...                  ...
#  95    95  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  96    96  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  97    97  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  98    98  Sea Surface Fragments | Enders  Ocean_Surface_Water
#  99    99  Sea Surface Fragments | Enders  Ocean_Surface_Water
#
#       Target_Compartment  RMSE  R2  Slope  Spearman_r  Pass_Spearman  \
#  0   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  1   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  2   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  3   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  4   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  ..                  ...   ...  ..    ...         ...            ...
#  95  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  96  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  97  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  98  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  99  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#
#      MPdensity_kg_m3        FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0       1223.294660  0.054891      5884.711542                    30.044884
#  1       1027.531967  0.740818      2868.534938                    54.291047
#  2       1112.195170  0.330629     21172.690691                    47.313693
#  3       1142.043586  0.902573      1849.708321                    75.362682
#  4       1183.945885  0.387262      3693.020138                   117.716668
#  ..              ...       ...              ...                          ...
#  95      1231.166859  0.851008      6058.951788                    27.518399
#  96      1238.635520  0.233781     11352.757679                    45.146966
#  97      1019.089303  0.532990       993.879397                    81.458540
#  98      1099.600655  0.380620      7326.505206                    32.499436
#  99      1149.916949  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case                Observed_dataset Emission_Compartment  \
#  0      0  Sea Surface Fragments | Enders  Coast_Surface_Water
#  1      1  Sea Surface Fragments | Enders  Coast_Surface_Water
#  2      2  Sea Surface Fragments | Enders  Coast_Surface_Water
#  3      3  Sea Surface Fragments | Enders  Coast_Surface_Water
#  4      4  Sea Surface Fragments | Enders  Coast_Surface_Water
#  ..   ...                             ...                  ...
#  95    95  Sea Surface Fragments | Enders  Coast_Surface_Water
#  96    96  Sea Surface Fragments | Enders  Coast_Surface_Water
#  97    97  Sea Surface Fragments | Enders  Coast_Surface_Water
#  98    98  Sea Surface Fragments | Enders  Coast_Surface_Water
#  99    99  Sea Surface Fragments | Enders  Coast_Surface_Water
#
#       Target_Compartment  RMSE  R2  Slope  Spearman_r  Pass_Spearman  \
#  0   Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  1   Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  2   Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  3   Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  4   Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  ..                  ...   ...  ..    ...         ...            ...
#  95  Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  96  Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  97  Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  98  Coast_Surface_Water   NaN NaN    NaN         NaN          False
#  99  Coast_Surface_Water   NaN NaN    NaN         NaN          False
#
#      MPdensity_kg_m3        FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0       1223.294660  0.054891      5884.711542                    30.044884
#  1       1027.531967  0.740818      2868.534938                    54.291047
#  2       1112.195170  0.330629     21172.690691                    47.313693
#  3       1142.043586  0.902573      1849.708321                    75.362682
#  4       1183.945885  0.387262      3693.020138                   117.716668
#  ..              ...       ...              ...                          ...
#  95      1231.166859  0.851008      6058.951788                    27.518399
#  96      1238.635520  0.233781     11352.757679                    45.146966
#  97      1019.089303  0.532990       993.879397                    81.458540
#  98      1099.600655  0.380620      7326.505206                    32.499436
#  99      1149.916949  0.823658      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case                Observed_dataset Emission_Compartment  \
#  0      0  Sea Surface Fragments | Enders  Coast_Surface_Water
#  1      1  Sea Surface Fragments | Enders  Coast_Surface_Water
#  2      2  Sea Surface Fragments | Enders  Coast_Surface_Water
#  3      3  Sea Surface Fragments | Enders  Coast_Surface_Water
#  4      4  Sea Surface Fragments | Enders  Coast_Surface_Water
#  ..   ...                             ...                  ...
#  95    95  Sea Surface Fragments | Enders  Coast_Surface_Water
#  96    96  Sea Surface Fragments | Enders  Coast_Surface_Water
#  97    97  Sea Surface Fragments | Enders  Coast_Surface_Water
#  98    98  Sea Surface Fragments | Enders  Coast_Surface_Water
#  99    99  Sea Surface Fragments | Enders  Coast_Surface_Water
#
#       Target_Compartment      RMSE        R2     Slope  Spearman_r  \
#  0   Ocean_Surface_Water       NaN       NaN       NaN         NaN
#  1   Ocean_Surface_Water  0.681048 -0.587461 -2.537056        -1.0
#  2   Ocean_Surface_Water  0.795525 -1.165986 -3.866528        -1.0
#  3   Ocean_Surface_Water  0.314093  0.662353 -3.024053        -1.0
#  4   Ocean_Surface_Water       NaN       NaN       NaN         NaN
#  ..                  ...       ...       ...       ...         ...
#  95  Ocean_Surface_Water  0.417362  0.403826 -3.557274        -1.0
#  96  Ocean_Surface_Water  0.801861 -1.200624 -3.653654        -1.0
#  97  Ocean_Surface_Water       NaN       NaN       NaN         NaN
#  98  Ocean_Surface_Water  0.777283 -1.067788 -3.779975        -1.0
#  99  Ocean_Surface_Water  0.387608  0.485798 -3.367621        -1.0
#
#      Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
#  0           False      1223.294660  0.054891      5884.711542
#  1            True      1027.531967  0.740818      2868.534938
#  2            True      1112.195170  0.330629     21172.690691
#  3            True      1142.043586  0.902573      1849.708321
#  4           False      1183.945885  0.387262      3693.020138
#  ..            ...              ...       ...              ...
#  95           True      1231.166859  0.851008      6058.951788
#  96           True      1238.635520  0.233781     11352.757679
#  97          False      1019.089303  0.532990       993.879397
#  98           True      1099.600655  0.380620      7326.505206
#  99           True      1149.916949  0.823658      3570.610973
#
#      t_frag_gen_FreeSurfaceWater
#  0                     30.044884
#  1                     54.291047
#  2                     47.313693
#  3                     75.362682
#  4                    117.716668
#  ..                          ...
#  95                    27.518399
#  96                    45.146966
#  97                    81.458540
#  98                    32.499436
#  99                    51.807228
#
#  [100 rows x 13 columns],
#      Case             Observed_dataset Emission_Compartment  \
#  0      0  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  1      1  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  2      2  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  3      3  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  4      4  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  ..   ...                          ...                  ...
#  95    95  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  96    96  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  97    97  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  98    98  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  99    99  Sea Surface Fibers | Enders  Ocean_Surface_Water
#
#       Target_Compartment      RMSE         R2     Slope  Spearman_r  \
#  0   Coast_Surface_Water       NaN        NaN       NaN         NaN
#  1   Coast_Surface_Water  1.431252 -12.123037 -1.968295        -1.0
#  2   Coast_Surface_Water       NaN        NaN       NaN         NaN
#  3   Coast_Surface_Water       NaN        NaN       NaN         NaN
#  4   Coast_Surface_Water       NaN        NaN       NaN         NaN
#  ..                  ...       ...        ...       ...         ...
#  95  Coast_Surface_Water  1.993462 -24.457643 -2.310156        -1.0
#  96  Coast_Surface_Water       NaN        NaN       NaN         NaN
#  97  Coast_Surface_Water       NaN        NaN       NaN         NaN
#  98  Coast_Surface_Water       NaN        NaN       NaN         NaN
#  99  Coast_Surface_Water  1.970113 -23.864781 -2.204984        -1.0
#
#      Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
#  0           False      1223.294660  0.054891      5884.711542
#  1            True      1027.531967  0.740818      2868.534938
#  2           False      1112.195170  0.330629     21172.690691
#  3           False      1142.043586  0.902573      1849.708321
#  4           False      1183.945885  0.387262      3693.020138
#  ..            ...              ...       ...              ...
#  95           True      1231.166859  0.851008      6058.951788
#  96          False      1238.635520  0.233781     11352.757679
#  97          False      1019.089303  0.532990       993.879397
#  98          False      1099.600655  0.380620      7326.505206
#  99           True      1149.916949  0.823658      3570.610973
#
#      t_frag_gen_FreeSurfaceWater
#  0                     30.044884
#  1                     54.291047
#  2                     47.313693
#  3                     75.362682
#  4                    117.716668
#  ..                          ...
#  95                    27.518399
#  96                    45.146966
#  97                    81.458540
#  98                    32.499436
#  99                    51.807228
#
#  [100 rows x 13 columns],
#      Case             Observed_dataset Emission_Compartment  \
#  0      0  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  1      1  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  2      2  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  3      3  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  4      4  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  ..   ...                          ...                  ...
#  95    95  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  96    96  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  97    97  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  98    98  Sea Surface Fibers | Enders  Ocean_Surface_Water
#  99    99  Sea Surface Fibers | Enders  Ocean_Surface_Water
#
#       Target_Compartment  RMSE  R2  Slope  Spearman_r  Pass_Spearman  \
#  0   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  1   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  2   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  3   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  4   Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  ..                  ...   ...  ..    ...         ...            ...
#  95  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  96  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  97  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  98  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#  99  Ocean_Surface_Water   NaN NaN    NaN         NaN          False
#
#      MPdensity_kg_m3        FI  t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0       1223.294660  0.054891      5884.711542                    30.044884
#  1       1027.531967  0.740818      2868.534938                    54.291047
# ...
#  98    98  Fibers in water | Eo   Surface_Freshwater  Surface_Freshwater   NaN
#  99    99  Fibers in water | Eo   Surface_Freshwater  Surface_Freshwater   NaN
#
#      R2  Slope  Spearman_r  Pass_Spearman  MPdensity_kg_m3        FI  \
#  0  NaN    NaN         NaN          False      1223.294660  0.054891
#  1  NaN    NaN         NaN          False      1027.531967  0.740818
#  2  NaN    NaN         NaN          False      1112.195170  0.330629
#  3  NaN    NaN         NaN          False      1142.043586  0.902573
#  4  NaN    NaN         NaN          False      1183.945885  0.387262
#  ..  ..    ...         ...            ...              ...       ...
#  95 NaN    NaN         NaN          False      1231.166859  0.851008
#  96 NaN    NaN         NaN          False      1238.635520  0.233781
#  97 NaN    NaN         NaN          False      1019.089303  0.532990
#  98 NaN    NaN         NaN          False      1099.600655  0.380620
#  99 NaN    NaN         NaN          False      1149.916949  0.823658
#
#      t_half_deg_free  t_frag_gen_FreeSurfaceWater
#  0       5884.711542                    30.044884
#  1       2868.534938                    54.291047
#  2      21172.690691                    47.313693
#  3       1849.708321                    75.362682
#  4       3693.020138                   117.716668
#  ..              ...                          ...
#  95      6058.951788                    27.518399
#  96     11352.757679                    45.146966
#  97       993.879397                    81.458540
#  98      7326.505206                    32.499436
#  99      3570.610973                    51.807228
#
#  [100 rows x 13 columns],
#      Case            Observed_dataset   Emission_Compartment  \
#  0      0  Fragments in sediment | Eo  Impacted_Soil_Surface
#  1      1  Fragments in sediment | Eo  Impacted_Soil_Surface
#  2      2  Fragments in sediment | Eo  Impacted_Soil_Surface
#  3      3  Fragments in sediment | Eo  Impacted_Soil_Surface
#  4      4  Fragments in sediment | Eo  Impacted_Soil_Surface
#  ..   ...                         ...                    ...
#  95    95  Fragments in sediment | Eo  Impacted_Soil_Surface
#  96    96  Fragments in sediment | Eo  Impacted_Soil_Surface
#  97    97  Fragments in sediment | Eo  Impacted_Soil_Surface
#  98    98  Fragments in sediment | Eo  Impacted_Soil_Surface
#  99    99  Fragments in sediment | Eo  Impacted_Soil_Surface
#
#     Target_Compartment      RMSE         R2     Slope  Spearman_r  \
#  0      Sediment_Ocean  1.705180 -10.122553 -3.364643        -1.0
#  1      Sediment_Ocean  1.693652  -9.972662 -3.840217        -1.0
#  2      Sediment_Ocean  1.645324  -9.355390 -3.454511        -1.0
#  3      Sediment_Ocean  1.505178  -7.666413 -3.689767        -1.0
#  4      Sediment_Ocean  1.910002 -12.955056 -3.629751        -1.0
#  ..                ...       ...        ...       ...         ...
#  95     Sediment_Ocean  1.676321  -9.749251 -3.944940        -1.0
#  96     Sediment_Ocean  1.714944 -10.250296 -3.497042        -1.0
#  97     Sediment_Ocean       NaN        NaN       NaN        -1.0
#  98     Sediment_Ocean  1.873667 -12.429154 -3.736933        -1.0
#  99     Sediment_Ocean  1.577587  -8.520292 -3.785259        -1.0
#
#      Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
#  0            True      1223.294660  0.054891      5884.711542
#  1            True      1027.531967  0.740818      2868.534938
#  2            True      1112.195170  0.330629     21172.690691
#  3            True      1142.043586  0.902573      1849.708321
#  4            True      1183.945885  0.387262      3693.020138
#  ..            ...              ...       ...              ...
#  95           True      1231.166859  0.851008      6058.951788
#  96           True      1238.635520  0.233781     11352.757679
#  97           True      1019.089303  0.532990       993.879397
#  98           True      1099.600655  0.380620      7326.505206
#  99           True      1149.916949  0.823658      3570.610973
#
#      t_frag_gen_FreeSurfaceWater
#  0                     30.044884
#  1                     54.291047
#  2                     47.313693
#  3                     75.362682
#  4                    117.716668
#  ..                          ...
#  95                    27.518399
#  96                    45.146966
#  97                    81.458540
#  98                    32.499436
#  99                    51.807228
#
#  [100 rows x 13 columns],
#      Case            Observed_dataset   Emission_Compartment  \
#  0      0  Fragments in sediment | Eo  Impacted_Soil_Surface
#  1      1  Fragments in sediment | Eo  Impacted_Soil_Surface
#  2      2  Fragments in sediment | Eo  Impacted_Soil_Surface
#  3      3  Fragments in sediment | Eo  Impacted_Soil_Surface
#  4      4  Fragments in sediment | Eo  Impacted_Soil_Surface
#  ..   ...                         ...                    ...
#  95    95  Fragments in sediment | Eo  Impacted_Soil_Surface
#  96    96  Fragments in sediment | Eo  Impacted_Soil_Surface
#  97    97  Fragments in sediment | Eo  Impacted_Soil_Surface
#  98    98  Fragments in sediment | Eo  Impacted_Soil_Surface
#  99    99  Fragments in sediment | Eo  Impacted_Soil_Surface
#
#     Target_Compartment      RMSE         R2     Slope  Spearman_r  \
#  0      Sediment_Coast  1.636751  -9.247767 -3.238306        -1.0
#  1      Sediment_Coast  1.568848  -8.415118 -3.674799        -1.0
#  2      Sediment_Coast  1.604754  -8.851016 -3.352349        -1.0
#  3      Sediment_Coast  1.419008  -6.702534 -3.563425        -1.0
#  4      Sediment_Coast  1.835620 -11.889307 -3.502910        -1.0
#  ..                ...       ...        ...       ...         ...
#  95     Sediment_Coast  1.606477  -8.872177 -3.818233        -1.0
#  96     Sediment_Coast  1.655608  -9.485254 -3.376329        -1.0
#  97     Sediment_Coast       NaN        NaN       NaN        -1.0
#  98     Sediment_Coast  1.818712 -11.652947 -3.621510        -1.0
#  99     Sediment_Coast  1.504329  -7.656643 -3.660425        -1.0
#
#      Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
#  0            True      1223.294660  0.054891      5884.711542
#  1            True      1027.531967  0.740818      2868.534938
#  2            True      1112.195170  0.330629     21172.690691
#  3            True      1142.043586  0.902573      1849.708321
#  4            True      1183.945885  0.387262      3693.020138
#  ..            ...              ...       ...              ...
#  95           True      1231.166859  0.851008      6058.951788
#  96           True      1238.635520  0.233781     11352.757679
#  97           True      1019.089303  0.532990       993.879397
#  98           True      1099.600655  0.380620      7326.505206
#  99           True      1149.916949  0.823658      3570.610973
#
#      t_frag_gen_FreeSurfaceWater
#  0                     30.044884
#  1                     54.291047
#  2                     47.313693
#  3                     75.362682
#  4                    117.716668
#  ..                          ...
#  95                    27.518399
#  96                    45.146966
#  97                    81.458540
#  98                    32.499436
#  99                    51.807228
#
#  [100 rows x 13 columns],
#      Case            Observed_dataset   Emission_Compartment  \
#  0      0  Fragments in sediment | Eo  Impacted_Soil_Surface
#  1      1  Fragments in sediment | Eo  Impacted_Soil_Surface
#  2      2  Fragments in sediment | Eo  Impacted_Soil_Surface
#  3      3  Fragments in sediment | Eo  Impacted_Soil_Surface
#  4      4  Fragments in sediment | Eo  Impacted_Soil_Surface
#  ..   ...                         ...                    ...
#  95    95  Fragments in sediment | Eo  Impacted_Soil_Surface
#  96    96  Fragments in sediment | Eo  Impacted_Soil_Surface
#  97    97  Fragments in sediment | Eo  Impacted_Soil_Surface
#  98    98  Fragments in sediment | Eo  Impacted_Soil_Surface
#  99    99  Fragments in sediment | Eo  Impacted_Soil_Surface
#
#     Target_Compartment      RMSE         R2     Slope  Spearman_r  \
#  0   Beaches_Deep_Soil  3.555363 -47.353935 -5.600652        -1.0
#  1   Beaches_Deep_Soil  3.253267 -39.485840 -6.005256        -1.0
#  2   Beaches_Deep_Soil  3.356112 -42.086052 -5.532602        -1.0
#  3   Beaches_Deep_Soil  3.584145 -48.139970 -6.185630        -1.0
#  4   Beaches_Deep_Soil  3.853947 -55.816595 -5.971918        -1.0
#  ..                ...       ...        ...       ...         ...
#  95  Beaches_Deep_Soil  3.524079 -46.506732 -6.171937        -1.0
#  96  Beaches_Deep_Soil  3.461682 -44.839318 -5.611845        -1.0
#  97  Beaches_Deep_Soil  3.060043 -34.819441 -5.207987        -1.0
#  98  Beaches_Deep_Soil  3.737001 -52.420795 -5.997968        -1.0
#  99  Beaches_Deep_Soil  3.541824 -46.986366 -6.149848        -1.0
#
#      Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
#  0            True      1223.294660  0.054891      5884.711542
#  1            True      1027.531967  0.740818      2868.534938
#  2            True      1112.195170  0.330629     21172.690691
#  3            True      1142.043586  0.902573      1849.708321
#  4            True      1183.945885  0.387262      3693.020138
#  ..            ...              ...       ...              ...
#  95           True      1231.166859  0.851008      6058.951788
#  96           True      1238.635520  0.233781     11352.757679
#  97           True      1019.089303  0.532990       993.879397
#  98           True      1099.600655  0.380620      7326.505206
#  99           True      1149.916949  0.823658      3570.610973
#
#      t_frag_gen_FreeSurfaceWater
#  0                     30.044884
#  1                     54.291047
#  2                     47.313693
#  3                     75.362682
#  4                    117.716668
#  ..                          ...
#  95                    27.518399
#  96                    45.146966
#  97                    81.458540
#  98                    32.499436
#  99                    51.807228
#
#  [100 rows x 13 columns],
#      Case            Observed_dataset   Emission_Compartment  \
#  0      0  Fragments in sediment | Eo  Impacted_Soil_Surface
#  1      1  Fragments in sediment | Eo  Impacted_Soil_Surface
#  2      2  Fragments in sediment | Eo  Impacted_Soil_Surface
#  3      3  Fragments in sediment | Eo  Impacted_Soil_Surface
#  4      4  Fragments in sediment | Eo  Impacted_Soil_Surface
#  ..   ...                         ...                    ...
#  95    95  Fragments in sediment | Eo  Impacted_Soil_Surface
#  96    96  Fragments in sediment | Eo  Impacted_Soil_Surface
#  97    97  Fragments in sediment | Eo  Impacted_Soil_Surface
#  98    98  Fragments in sediment | Eo  Impacted_Soil_Surface
#  99    99  Fragments in sediment | Eo  Impacted_Soil_Surface
#
#        Target_Compartment      RMSE         R2     Slope  Spearman_r  \
#  0   Beaches_Soil_Surface  3.273997 -40.003437 -5.073610        -1.0
#  1   Beaches_Soil_Surface  2.882504 -30.783648 -5.333293        -1.0
#  2   Beaches_Soil_Surface  3.202175 -38.224175 -5.238057        -1.0
#  3   Beaches_Soil_Surface  3.154541 -37.065901 -5.421987        -1.0
#  4   Beaches_Soil_Surface  3.517515 -46.329925 -5.351554        -1.0
#  ..                   ...       ...        ...       ...         ...
#  95  Beaches_Soil_Surface  3.243856 -39.251947 -5.650590        -1.0
#  96  Beaches_Soil_Surface  3.249977 -39.403998 -5.209994        -1.0
#  97  Beaches_Soil_Surface  2.537810 -23.636670 -4.308837        -1.0
#  98  Beaches_Soil_Surface  3.479228 -45.305190 -5.513918        -1.0
#  99  Beaches_Soil_Surface  3.199281 -38.153311 -5.522590        -1.0
#
#      Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
#  0            True      1223.294660  0.054891      5884.711542
#  1            True      1027.531967  0.740818      2868.534938
#  2            True      1112.195170  0.330629     21172.690691
#  3            True      1142.043586  0.902573      1849.708321
#  4            True      1183.945885  0.387262      3693.020138
#  ..            ...              ...       ...              ...
#  95           True      1231.166859  0.851008      6058.951788
#  96           True      1238.635520  0.233781     11352.757679
#  97           True      1019.089303  0.532990       993.879397
#  98           True      1099.600655  0.380620      7326.505206
#  99           True      1149.916949  0.823658      3570.610973
#
#      t_frag_gen_FreeSurfaceWater
#  0                     30.044884
#  1                     54.291047
#  2                     47.313693
#  3                     75.362682
#  4                    117.716668
#  ..                          ...
#  95                    27.518399
#  96                    45.146966
#  97                    81.458540
#  98                    32.499436
#  99                    51.807228
#
#  [100 rows x 13 columns],
#      Case            Observed_dataset   Emission_Compartment  \
#  0      0  Fragments in sediment | Eo  Impacted_Soil_Surface
#  1      1  Fragments in sediment | Eo  Impacted_Soil_Surface
#  2      2  Fragments in sediment | Eo  Impacted_Soil_Surface
#  3      3  Fragments in sediment | Eo  Impacted_Soil_Surface
#  4      4  Fragments in sediment | Eo  Impacted_Soil_Surface
#  ..   ...                         ...                    ...
#  95    95  Fragments in sediment | Eo  Impacted_Soil_Surface
#  96    96  Fragments in sediment | Eo  Impacted_Soil_Surface
#  97    97  Fragments in sediment | Eo  Impacted_Soil_Surface
#  98    98  Fragments in sediment | Eo  Impacted_Soil_Surface
#  99    99  Fragments in sediment | Eo  Impacted_Soil_Surface
#
#       Target_Compartment      RMSE         R2     Slope  Spearman_r  \
#  0   Sediment_Freshwater  2.575486 -24.373615 -4.015911        -1.0
#  1   Sediment_Freshwater  2.507052 -23.043103 -4.441051        -1.0
#  2   Sediment_Freshwater  2.712110 -27.137046 -4.416473        -1.0
#  3   Sediment_Freshwater  2.227175 -17.974596 -4.131540        -1.0
#  4   Sediment_Freshwater  2.728718 -27.482690 -4.198778        -1.0
#  ..                  ...       ...        ...       ...         ...
#  95  Sediment_Freshwater  2.546440 -23.804522 -4.599037        -1.0
#  96  Sediment_Freshwater  2.664204 -26.151807 -4.278175        -1.0
#  97  Sediment_Freshwater  2.789607 -28.768024 -4.356081        -1.0
#  98  Sediment_Freshwater  2.822833 -29.481341 -4.495068        -1.0
#  99  Sediment_Freshwater  2.401675 -21.064416 -4.362651        -1.0
#
#      Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
#  0            True      1223.294660  0.054891      5884.711542
#  1            True      1027.531967  0.740818      2868.534938
#  2            True      1112.195170  0.330629     21172.690691
#  3            True      1142.043586  0.902573      1849.708321
#  4            True      1183.945885  0.387262      3693.020138
#  ..            ...              ...       ...              ...
#  95           True      1231.166859  0.851008      6058.951788
#  96           True      1238.635520  0.233781     11352.757679
#  97           True      1019.089303  0.532990       993.879397
#  98           True      1099.600655  0.380620      7326.505206
#  99           True      1149.916949  0.823658      3570.610973
#
#      t_frag_gen_FreeSurfaceWater
#  0                     30.044884
#  1                     54.291047
#  2                     47.313693
#  3                     75.362682
#  4                    117.716668
#  ..                          ...
#  95                    27.518399
#  96                    45.146966
#  97                    81.458540
#  98                    32.499436
#  99                    51.807228
#
#  [100 rows x 13 columns]]

# %%
# Sort ascending by RMSE (best fits first)
results_sorted_all = results_df.sort_values("RMSE", ascending=True)

# Keep e.g. top 20 best-fitting combinations
top_results = results_sorted_all.head(20)

# %%
top_results
# Out:
#       Case               Observed_dataset   Emission_Compartment  \
# 1213    13     Sea Surface all | Isobe L2     Surface_Freshwater
# 454     14        Fragments in water | Eo     Surface_Freshwater
# 1293    13     Sea Surface all | Isobe L3     Surface_Freshwater
# 1202     2     Sea Surface all | Isobe L2     Surface_Freshwater
# 1282     2     Sea Surface all | Isobe L3     Surface_Freshwater
# 446      6        Fragments in water | Eo     Surface_Freshwater
# 1350    10     Sea Surface all | Isobe L3    Coast_Surface_Water
# 523      3           Fibers in water | Eo     Surface_Freshwater
# 450     10        Fragments in water | Eo     Surface_Freshwater
# 1294    14     Sea Surface all | Isobe L3     Surface_Freshwater
# 1270    10     Sea Surface all | Isobe L2    Coast_Surface_Water
# 1214    14     Sea Surface all | Isobe L2     Surface_Freshwater
# 1290    10     Sea Surface all | Isobe L3     Surface_Freshwater
# 1210    10     Sea Surface all | Isobe L2     Surface_Freshwater
# 723      3     Fragments in sediment | Eo     Surface_Freshwater
# 1509     9   Sea Surface Fragments | Song  Impacted_Soil_Surface
# 1286     6     Sea Surface all | Isobe L3     Surface_Freshwater
# 729      9     Fragments in sediment | Eo     Surface_Freshwater
# 1110    10  Fresh water sediments | Imhof  Impacted_Soil_Surface
# 1106     6  Fresh water sediments | Imhof  Impacted_Soil_Surface
#
#         Target_Compartment      RMSE        R2     Slope  Spearman_r  \
# 1213   Coast_Surface_Water  0.186895  0.567600 -1.106920        -1.0
# 454        Bulk_Freshwater  0.187929  0.926856 -1.953069        -1.0
# 1293   Coast_Surface_Water  0.188085  0.552097 -1.106920        -1.0
# 1202   Coast_Surface_Water  0.189423  0.555822 -0.976781        -1.0
# 1282   Coast_Surface_Water  0.189570  0.544999 -0.976781        -1.0
# 446        Bulk_Freshwater  0.191544  0.924015 -2.016675        -1.0
# 1350   Ocean_Surface_Water  0.196613  0.510561 -0.919336        -1.0
# 523        Bulk_Freshwater  0.197610  0.417037 -1.078888        -1.0
# 450        Bulk_Freshwater  0.197911  0.918880 -1.938019        -1.0
# 1294   Coast_Surface_Water  0.199559  0.495782 -0.940302        -1.0
# 1270   Ocean_Surface_Water  0.201197  0.498890 -0.919336        -1.0
# 1214   Coast_Surface_Water  0.203391  0.487900 -0.940302        -1.0
# 1290   Coast_Surface_Water  0.203780  0.474231 -1.071980        -1.0
# 1210   Coast_Surface_Water  0.204319  0.483215 -1.071980        -1.0
# 723   Beaches_Soil_Surface  0.204803  0.839552 -1.986410        -1.0
# 1509   Ocean_Surface_Water  0.208144  0.919378 -2.740697        -1.0
# 1286   Coast_Surface_Water  0.210948  0.436592 -0.898897        -1.0
# 729   Beaches_Soil_Surface  0.215345  0.822608 -2.403956        -1.0
# 1110    Surface_Freshwater  0.216951  0.546750 -2.784194        -1.0
# 1106    Surface_Freshwater  0.217854  0.542971 -2.736610        -1.0
#
#       Pass_Spearman  MPdensity_kg_m3        FI  t_half_deg_free  \
# 1213           True       961.519499  0.603366      4384.922339
# 454            True       856.834375  0.450996      4610.300644
# 1293           True       961.519499  0.603366      4384.922339
# 1202           True       949.180258  0.330629      5037.980205
# 1282           True       949.180258  0.330629      5037.980205
# 446            True       735.394318  0.224775      4095.613401
# 1350           True       928.013133  0.118571      4555.026552
# 523            True       987.645770  0.902573      4326.028802
# 450            True       928.013133  0.118571      4555.026552
# 1294           True       856.834375  0.450996      4610.300644
# 1270           True       928.013133  0.118571      4555.026552
# 1214           True       856.834375  0.450996      4610.300644
# 1290           True       928.013133  0.118571      4555.026552
# 1210           True       928.013133  0.118571      4555.026552
# 723            True       987.645770  0.902573      4326.028802
# 1509           True       822.695580  0.966201      4765.893578
# 1286           True       735.394318  0.224775      4095.613401
# 729            True       822.695580  0.966201      4765.893578
# 1110           True       928.013133  0.118571      4555.026552
# 1106           True       735.394318  0.224775      4095.613401
#
#       t_frag_gen_FreeSurfaceWater
# 1213                    22.091539
# 454                     56.050699
# 1293                    22.091539
# 1202                    30.721058
# 1282                    30.721058
# 446                     40.125766
# 1350                     7.845831
# 523                     48.933431
# 450                      7.845831
# 1294                    56.050699
# 1270                     7.845831
# 1214                    56.050699
# 1290                     7.845831
# 1210                     7.845831
# 723                     48.933431
# 1509                    59.965600
# 1286                    40.125766
# 729                     59.965600
# 1110                     7.845831
# 1106                    40.125766

# %% [markdown]
# From top results run model and plot overlays with observed data

# %%
from utopia.monte_carlo.montecarlo_analysis_paper import run_and_plot_top_results
run_and_plot_top_results(top_results,data_data, config_data)

# %% [markdown]
# Correlation heat maps for top results

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap for the top results
corr = top_results[["RMSE", "R2", "Slope", "MPdensity_kg_m3", "FI", "t_half_deg_free", "t_frag_gen_FreeSurfaceWater"]].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation matrix (Top 10 best fits)")
plt.show()

# %%
# Pair-wise relationships for the top results
sns.pairplot(
    top_results,
    vars=["MPdensity_kg_m3", "FI", "t_half_deg_free", "t_frag_gen_FreeSurfaceWater","RMSE"],
    hue="Target_Compartment",
    corner=True
)
plt.suptitle("Parameter relationships for best-fitting runs", y=1.02)
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

params = ["MPdensity_kg_m3", "FI", "t_half_deg_free", "t_frag_gen_FreeSurfaceWater"]

for ax, param in zip(axes.ravel(), params):
    sns.scatterplot(data=top_results, x=param, y="RMSE", hue="Target_Compartment", ax=ax)
    ax.set_title(f"RMSE vs {param}")

plt.tight_layout()
plt.show()

# %%
# Pearson & Spearman correlation between Density and FI for all results

# Pearson tests linear correlation.

# Spearman tests monotonic correlation (rank-based, robust to nonlinearities).

# If p < 0.05, the correlation is statistically significant.

from scipy.stats import pearsonr, spearmanr

x = top_results["MPdensity_kg_m3"]
y = top_results["FI"]

pearson_corr, pearson_p = pearsonr(x, y)
spearman_corr, spearman_p = spearmanr(x, y)

print(f"Pearson r = {pearson_corr:.3f}, p = {pearson_p:.3e}")
print(f"Spearman ρ = {spearman_corr:.3f}, p = {spearman_p:.3e}")

import seaborn as sns
import matplotlib.pyplot as plt

sns.lmplot(
    data=top_results, 
    x="MPdensity_kg_m3", 
    y="FI", 
    #hue="Target_Compartment", 
    height=6, aspect=1.2,
    scatter_kws={"alpha": 0.7}
)
plt.title("Density vs FI (with regression fits)")
plt.show()
# Out:
# Pearson r = 0.114, p = 6.323e-01
# Spearman ρ = 0.130, p = 5.844e-01

# %%
# Pearson & Spearman correlation between Density and FI for best fits (e.g. lowest 10% RMSE)

threshold = top_results["RMSE"].quantile(0.1)  # lowest 10% of RMSE
best_fits = top_results[top_results["RMSE"] <= threshold]

pearson_corr, _ = pearsonr(best_fits["MPdensity_kg_m3"], best_fits["FI"])
print(f"Best fits Pearson r = {pearson_corr:.3f}")


sns.lmplot(
    data=best_fits, 
    x="MPdensity_kg_m3", 
    y="FI", 
    hue="Target_Compartment", 
    height=6, aspect=1.2,
    scatter_kws={"alpha": 0.7}
)
plt.title("Density vs FI (with regression fits)")
plt.show()
# Out:
# Best fits Pearson r = 0.114

# %%
from scipy.stats import pearsonr, spearmanr
import pandas as pd

# Keep only best 10% RMSE across all compartments
threshold = top_results["RMSE"].quantile(0.1)
best_fits = top_results[top_results["RMSE"] <= threshold]

results = []

for comp in best_fits["Target_Compartment"].unique():
    subset = best_fits[best_fits["Target_Compartment"] == comp]
    
    if len(subset) > 2:  # need at least 3 points
        pearson_corr, pearson_p = pearsonr(subset["MPdensity_kg_m3"], subset["FI"])
        spearman_corr, spearman_p = spearmanr(subset["MPdensity_kg_m3"], subset["FI"])
    else:
        pearson_corr, pearson_p, spearman_corr, spearman_p = [None]*4
    
    results.append({
        "Target_Compartment": comp,
        "Pearson_r": pearson_corr,
        "Pearson_p": pearson_p,
        "Spearman_rho": spearman_corr,
        "Spearman_p": spearman_p,
        "n_points": len(subset)
    })

correlation_best = pd.DataFrame(results)
print(correlation_best)
# Out:
#     Target_Compartment Pearson_r Pearson_p Spearman_rho Spearman_p  n_points
# 0  Coast_Surface_Water      None      None         None       None         1
# 1      Bulk_Freshwater      None      None         None       None         1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# --- pick best fits per compartment (lowest 10% RMSE) ---
best_fits_list = []

for comp in top_results["Target_Compartment"].unique():
    subset = top_results[top_results["Target_Compartment"] == comp]
    if len(subset) > 2:
        threshold = subset["RMSE"].quantile(0.1)   # lowest 10%
        best_subset = subset[subset["RMSE"] <= threshold]
        best_fits_list.append(best_subset)

best_fits = pd.concat(best_fits_list, ignore_index=True)

# --- plot each compartment separately ---
g = sns.lmplot(
    data=best_fits,
    x="MPdensity_kg_m3",
    y="FI",
    col="Target_Compartment",   # separate plot per compartment
    col_wrap=2,                 # wrap panels (2 per row)
    height=4,
    scatter_kws={"alpha": 0.7},
    line_kws={"color": "black"}
)

g.set_titles("{col_name}")
plt.suptitle("Density vs FI (Best RMSE fits, per compartment)", y=1.05)
plt.show()

# %% [markdown]
# ### Plot sensitivity indices for each output variable.  Monaco uses the D-VARS approach to calculating global sensitivity indices.

# %%
sim.outvars
# Out:
# {'Spearman_r': <monaco.mc_var.OutVar at 0x16cc2281650>,
#  'Spearman_p': <monaco.mc_var.OutVar at 0x16cbfaadc90>,
#  'Pass_Spearman': <monaco.mc_var.OutVar at 0x16cbd9294d0>,
#  'RMSE': <monaco.mc_var.OutVar at 0x16cbfb8df50>,
#  'R_squared': <monaco.mc_var.OutVar at 0x16cbfb8c990>,
#  'Model_slope': <monaco.mc_var.OutVar at 0x16cc1deb590>,
#  'Model_intercept': <monaco.mc_var.OutVar at 0x16cc1deba90>,
#  'Target_compartment': <monaco.mc_var.OutVar at 0x16cc1dea490>,
#  'Emission_compartment': <monaco.mc_var.OutVar at 0x16cc1de8550>}

# %%
sim.calcSensitivities("C_g_m3_Ocean_Surface_Water")
fig, ax = sim.outvars["C_g_m3_Ocean_Surface_Water"].plotSensitivities()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sim.calcSensitivities("C_g_m3_Ocean_Surface_Water")
#       2 fig, ax = sim.outvars["C_g_m3_Ocean_Surface_Water"].plotSensitivities()
#
# File c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\mc_sim.py:916, in Sim.calcSensitivities(self, outvarnames, tol, verbose)
#     913 outvarnames = get_list(outvarnames)
#     915 for outvarname in outvarnames:
# --> 916     if not self.outvars[outvarname].isscalar:
#     917         vwarn(self.verbose, f"Output variable '{outvarname}' is not scalar," +
#     918                              'skipping sensitivity calculations.')
#     919     else:
#
# KeyError: 'C_g_m3_Ocean_Surface_Water'

# %%
sim.calcSensitivities("persistence_number")
fig, ax = sim.outvars["persistence_number"].plotSensitivities()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sim.calcSensitivities("persistence_number")
#       2 fig, ax = sim.outvars["persistence_number"].plotSensitivities()
#
# File c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\mc_sim.py:916, in Sim.calcSensitivities(self, outvarnames, tol, verbose)
#     913 outvarnames = get_list(outvarnames)
#     915 for outvarname in outvarnames:
# --> 916     if not self.outvars[outvarname].isscalar:
#     917         vwarn(self.verbose, f"Output variable '{outvarname}' is not scalar," +
#     918                              'skipping sensitivity calculations.')
#     919     else:
#
# KeyError: 'persistence_number'

# %%
import matplotlib.pyplot as plt

for var in sim.outvars:
    print(f"Variable: {var}")
    sim.calcSensitivities(var)
    fig, ax = sim.outvars[var].plotSensitivities()

    plt.show()
# Out:
# Variable: Spearman_r
# Calculating sensitivity indices for 'Spearman_r'...
# Calculating optimal hyperparameters Φ for 'Spearman_r' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# Variable: Spearman_p
# Calculating sensitivity indices for 'Spearman_p'...
# Calculating optimal hyperparameters Φ for 'Spearman_p' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# Variable: Pass_Spearman
# Calculating sensitivity indices for 'Pass_Spearman'...
# Calculating optimal hyperparameters Φ for 'Pass_Spearman' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# Variable: RMSE
# Calculating sensitivity indices for 'RMSE'...
# Calculating optimal hyperparameters Φ for 'RMSE' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# Variable: R_squared
# Calculating sensitivity indices for 'R_squared'...
# Calculating optimal hyperparameters Φ for 'R_squared' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# Variable: Model_slope
# Calculating sensitivity indices for 'Model_slope'...
# Calculating optimal hyperparameters Φ for 'Model_slope' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# Variable: Model_intercept
# Calculating sensitivity indices for 'Model_intercept'...
# Calculating optimal hyperparameters Φ for 'Model_intercept' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# Variable: Target_compartment
# Calculating sensitivity indices for 'Target_compartment'...
# Calculating optimal hyperparameters Φ for 'Target_compartment' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\dvars_sensitivity.py:277: RuntimeWarning: divide by zero encountered in log
#   L = np.log(Rdet)/m + m*np.log(L_inner.T @ Rinv @ L_inner)
# c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\scipy\optimize\_numdiff.py:686: RuntimeWarning: invalid value encountered in subtract
#   df = [f_eval - f0 for f_eval in f_evals]
# c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\dvars_sensitivity.py:93: RuntimeWarning: invalid value encountered in divide
#   ratios = sensitivities/sum(sensitivities)
# Variable: Emission_compartment
# Calculating sensitivity indices for 'Emission_compartment'...
# Calculating optimal hyperparameters Φ for 'Emission_compartment' covariances...
# Done calculating optimal hyperparameters.
# Done calculating sensitivity indices.
# c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\dvars_sensitivity.py:277: RuntimeWarning: divide by zero encountered in log
#   L = np.log(Rdet)/m + m*np.log(L_inner.T @ Rinv @ L_inner)
# c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\scipy\optimize\_numdiff.py:686: RuntimeWarning: invalid value encountered in subtract
#   df = [f_eval - f0 for f_eval in f_evals]
# c:\Users\PradoDomercq\AppData\Local\miniconda3\envs\utopia_envP11\Lib\site-packages\monaco\dvars_sensitivity.py:93: RuntimeWarning: invalid value encountered in divide
#   ratios = sensitivities/sum(sensitivities)

# %% [markdown]
# ### Plot

# %%
sim.outvars.keys()
# Out:
# dict_keys(['Coast_Surface_Water_Spearman_r', 'Coast_Surface_Water_Spearman_p', 'Coast_Surface_Water_Pass_Spearman', 'Coast_Surface_Water_RMSE', 'Coast_Surface_Water_R_squared', 'Coast_Surface_Water_Model_slope', 'Coast_Surface_Water_Model_intercept', 'Ocean_Surface_Water_Spearman_r', 'Ocean_Surface_Water_Spearman_p', 'Ocean_Surface_Water_Pass_Spearman', 'Ocean_Surface_Water_RMSE', 'Ocean_Surface_Water_R_squared', 'Ocean_Surface_Water_Model_slope', 'Ocean_Surface_Water_Model_intercept', 'residence_time_mass', 'residence_time_number', 'persistence_mass', 'persistence_number'])

# %%
mc.multi_plot([sim.invars["MPdensity_kg_m3"],sim.outvars["persistence_mass"]],title="persistence_mass vs density",cov_plot=True)
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  (<Axes: xlabel='MPdensity_kg_m3'>,
#   <Axes: ylabel='persistence_mass'>,
#   <Axes: >))
